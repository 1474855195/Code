# %%
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")
#读取文件  
import os 
import csv
for root, dirs, files in os.walk('dataset'):  
        print(root) #当前目录路径
        print(files) #当前路径下所有非目录子文件
#进入dataset文件
os.chdir('dataset')
# Out:
# dataset
# ['ant-1.3.csv', 'ant-1.4.csv', 'ant-1.5.csv', 'ant-1.6.csv', 'ant-1.7.csv', 'camel-1.0.csv', 'camel-1.2.csv', 'camel-1.4.csv', 'camel-1.6.csv', 'ivy-1.1.csv', 'ivy-1.4.csv', 'ivy-2.0.csv', 'jedit-3.2.csv', 'jedit-4.0.csv', 'jedit-4.1.csv', 'jedit-4.2.csv', 'jedit-4.3.csv', 'log4j-1.0.csv', 'log4j-1.1.csv', 'log4j-1.2.csv', 'lucene-2.0.csv', 'lucene-2.2.csv', 'lucene-2.4.csv', 'poi-1.5.csv', 'poi-2.0.csv', 'poi-2.5.csv', 'poi-3.0.csv', 'synapse-1.0.csv', 'synapse-1.1.csv', 'synapse-1.2.csv', 'velocity-1.4.csv', 'velocity-1.5.csv', 'velocity-1.6.csv', 'xalan-2.4.csv', 'xalan-2.5.csv', 'xalan-2.6.csv', 'xalan-2.7.csv', 'xerces-1.2.csv', 'xerces-1.3.csv', 'xerces-1.4.csv']

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import sklearn.model_selection as sk_model_selection
from hyperopt import fmin,tpe,hp,partial,anneal,rand
from sklearn import metrics
import time

# %%
#写入文件函数
def writercsv(file_path,param,G):
    if os.path.isfile(file_path):
        with open(file_path,'a',newline='')as f:
            csv_write=csv.writer(f,dialect='excel')
            csv_write.writerow(G)
    else:
        with open(file_path,'w',newline='')as f:
            csv_write=csv.writer(f,dialect='excel')
            csv_write.writerow(param)
            csv_write.writerow(G)
#文件路径
file_path='..\Anneal_SVC_10.csv'
param=['Precision','Recall','F-measure','AUC','kernel','C','coef0',
       'MSE_Default','MSE_TPE','Bias_Default','Bias_TPE','var_Default','var_TPE','Time']

# %%
#顺序读取文件进行实验
num=0
while num<39:
    #读取文件
    df1=pd.read_csv(files[num],header=0)
    df2=pd.read_csv(files[num+1],header=0)
    print(files[num],"->",files[num+1])
    #调参实验
    x_train=df1.iloc[:,0:19].values
    y_train=df1.iloc[:,20].values
    x_test=df2.iloc[:,0:19].values
    y_true=df2.iloc[:,20].values
    #特征选择
    from skfeature.function.statistical_based import CFS
    feature_index = CFS.cfs(x_train,y_train) # 在训练集上训练
    num_feature = 10 # 从原数据集中选择10个特征
    t_train = x_train[:,feature_index[0:num_feature]] # 转换训练集
    t_test = x_test[:,feature_index[0:num_feature]] # 转换测试集
    
    def SVM(args):
        SVC_H=SVC(probability=True,kernel=args['kernel'],C=float(args['C']),coef0=float(args['coef0']))
        roc_auc=sk_model_selection.cross_val_score(SVC_H,t_train,y_train,scoring='roc_auc',cv=5)  
        return -roc_auc.mean()
    #参数空间
    space={'kernel': hp.choice('kernel',['sigmoid']),
        'C': hp.uniform('C',1.0,10.0),
        'coef0': hp.uniform('coef0',1.0,10.0)}
    #代理函数
    #algo=partial(tpe.suggest)
    #algo=partial(rand.suggest)
    algo=partial(anneal.suggest)

    time_start = time.process_time()
    best = fmin(SVM,space=space,algo = algo,max_evals=200)
    time_end = time.process_time()  # 记录结束时间
    time_sum = time_end - time_start  # 计算的时间差为程序的执行时间，单位为秒/s
    #设置离散变量
    best['kernel']='sigmoid'
    #参数带回实验进行预测
    model=SVC(probability=True,kernel=best['kernel'],C=float(best['C']),coef0=float(best['coef0']))
    model.fit(t_train,y_train)
    y_pred=model.predict(t_test)
    #评分
    G=[]
    probas=model.predict_proba(t_test)
    fpr,tpr,thresholds=roc_curve(y_true,probas[:,1])
    auc=metrics.auc(fpr,tpr)
    f_measure=metrics.f1_score(y_true,y_pred,average='weighted')
    recall=metrics.recall_score(y_true,y_pred,average='weighted')
    precision=metrics.precision_score(y_true,y_pred,average='weighted')
    G.append(precision)
    G.append(recall)
    G.append(f_measure)
    G.append(auc)
    G.append(best['kernel'])
    G.append(best['C'])
    G.append(best['coef0'])
    #计算模型稳定性
    model_d=SVC(probability=True)
    from mlxtend.evaluate import bias_variance_decomp
    MSE_Default,Bias_Default,var_Default=bias_variance_decomp(model_d,t_train,y_train,t_test,y_true,
                                  loss='mse',num_rounds=100,random_seed=1)
    MSE_TPE,Bias_TPE,var_TPE=bias_variance_decomp(model,t_train,y_train,t_test,y_true,
                                  loss='mse',num_rounds=100,random_seed=1)
    G.append(MSE_Default)
    G.append(MSE_TPE)
    G.append(Bias_Default)
    G.append(Bias_TPE)
    G.append(var_Default)
    G.append(var_TPE)
    G.append(time_sum)
    #写入文件
    writercsv(file_path,param,G)
    print('写入文件成功')
    #版本变化
    num=num+1
    print(num)
    #项目变化
    if((num==4) or (num==8)or(num==11)or(num==16)or(num==19)or(num==22)or(num==26)or(num==29)or(num==32)or(num==36)):
        num=num+1
        print("项目变化",num)
# Out:
# ant-1.3.csv -> ant-1.4.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:03<00:00, 59.88trial/s, best loss: -0.6714285714285715]
# 写入文件成功
# 1
# ant-1.4.csv -> ant-1.5.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:05<00:00, 38.58trial/s, best loss: -0.6162735155790712]
# 写入文件成功
# 2
# ant-1.5.csv -> ant-1.6.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:06<00:00, 33.08trial/s, best loss: -0.7971698113207546]
# 写入文件成功
# 3
# ant-1.6.csv -> ant-1.7.csv
# 100%|██████████████████████████████████████████████| 200/200 [00:14<00:00, 13.67trial/s, best loss: -0.814165409753645]
# 写入文件成功
# 4
# 项目变化 5
# camel-1.0.csv -> camel-1.2.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:03<00:00, 50.97trial/s, best loss: -0.7052913752913753]
# 写入文件成功
# 6
# camel-1.2.csv -> camel-1.4.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:52<00:00,  3.82trial/s, best loss: -0.5939068769029029]
# 写入文件成功
# 7
# camel-1.4.csv -> camel-1.6.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:51<00:00,  3.91trial/s, best loss: -0.7108795791051097]
# 写入文件成功
# 8
# 项目变化 9
# ivy-1.1.csv -> ivy-1.4.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:04<00:00, 48.64trial/s, best loss: -0.7630341880341881]
# 写入文件成功
# 10
# ivy-1.4.csv -> ivy-2.0.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:04<00:00, 44.09trial/s, best loss: -0.6255555555555554]
# 写入文件成功
# 11
# 项目变化 12
# jedit-3.2.csv -> jedit-4.0.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:11<00:00, 16.96trial/s, best loss: -0.7697280613947279]
# 写入文件成功
# 13
# jedit-4.0.csv -> jedit-4.1.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:11<00:00, 18.06trial/s, best loss: -0.7566697502312674]
# 写入文件成功
# 14
# jedit-4.1.csv -> jedit-4.2.csv
# 100%|██████████████████████████████████████████████| 200/200 [00:11<00:00, 17.00trial/s, best loss: -0.792154640764724]
# 写入文件成功
# 15
# jedit-4.2.csv -> jedit-4.3.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:09<00:00, 21.74trial/s, best loss: -0.8374355158730159]
# 写入文件成功
# 16
# 项目变化 17
# log4j-1.0.csv -> log4j-1.1.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:03<00:00, 52.15trial/s, best loss: -0.7982539682539682]
# 写入文件成功
# 18
# log4j-1.1.csv -> log4j-1.2.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:03<00:00, 55.76trial/s, best loss: -0.7343537414965986]
# 写入文件成功
# 19
# 项目变化 20
# lucene-2.0.csv -> lucene-2.2.csv
# 100%|██████████████████████████████████████████████| 200/200 [00:09<00:00, 21.72trial/s, best loss: -0.736229462545252]
# 写入文件成功
# 21
# lucene-2.2.csv -> lucene-2.4.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:11<00:00, 16.72trial/s, best loss: -0.6645941825005865]
# 写入文件成功
# 22
# 项目变化 23
# poi-1.5.csv -> poi-2.0.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:11<00:00, 17.96trial/s, best loss: -0.7698233730878922]
# 写入文件成功
# 24
# poi-2.0.csv -> poi-2.5.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:07<00:00, 26.78trial/s, best loss: -0.4638265306122449]
# 写入文件成功
# 25
# poi-2.5.csv -> poi-3.0.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:22<00:00,  8.84trial/s, best loss: -0.7307031638052046]
# 写入文件成功
# 26
# 项目变化 27
# synapse-1.0.csv -> synapse-1.1.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:03<00:00, 65.10trial/s, best loss: -0.8051313628899835]
# 写入文件成功
# 28
# synapse-1.1.csv -> synapse-1.2.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:07<00:00, 26.81trial/s, best loss: -0.7196101641414142]
# 写入文件成功
# 29
# 项目变化 30
# velocity-1.4.csv -> velocity-1.5.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:05<00:00, 33.93trial/s, best loss: -0.7521864623243933]
# 写入文件成功
# 31
# velocity-1.5.csv -> velocity-1.6.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:08<00:00, 24.69trial/s, best loss: -0.6267569786535304]
# 写入文件成功
# 32
# 项目变化 33
# xalan-2.4.csv -> xalan-2.5.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:32<00:00,  6.08trial/s, best loss: -0.7579516678177214]
# 写入文件成功
# 34
# xalan-2.5.csv -> xalan-2.6.csv
# 100%|█████████████████████████████████████████████| 200/200 [01:58<00:00,  1.68trial/s, best loss: -0.6139377547294931]
# 写入文件成功
# 35
# xalan-2.6.csv -> xalan-2.7.csv
# 100%|██████████████████████████████████████████████| 200/200 [02:18<00:00,  1.44trial/s, best loss: -0.598870379505074]
# 写入文件成功
# 36
# 项目变化 37
# xerces-1.2.csv -> xerces-1.3.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:14<00:00, 13.95trial/s, best loss: -0.5722896281800391]
# 写入文件成功
# 38
# xerces-1.3.csv -> xerces-1.4.csv
# 100%|█████████████████████████████████████████████| 200/200 [00:20<00:00,  9.96trial/s, best loss: -0.6992604200310968]
# 写入文件成功
# 39
